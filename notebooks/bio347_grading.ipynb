# %% [markdown]
# # Grading for BIO 347

# %%
import numpy as np
import pandas as pd

# %%
# Load DataFrame
df = pd.read_csv('activity.csv')

df
# Out:
#                                     L01                                  L02  \
# 0            abrar.uddin@stonybrook.edu           abrar.uddin@stonybrook.edu
# 1             agam.singh@stonybrook.edu            agam.singh@stonybrook.edu
# 2            aisha.m.ali@stonybrook.edu           aisha.m.ali@stonybrook.edu
# 3        alex.feldewerth@stonybrook.edu       alex.feldewerth@stonybrook.edu
# 4         alvin.varghese@stonybrook.edu        alvin.varghese@stonybrook.edu
# 5        andrew.sahawneh@stonybrook.edu       andrew.sahawneh@stonybrook.edu
# 6             areej.niaz@stonybrook.edu            areej.niaz@stonybrook.edu
# 7              arfan.ali@stonybrook.edu             arfan.ali@stonybrook.edu
# 8          benjamin.wu.2@stonybrook.edu         benjamin.wu.2@stonybrook.edu
# 9       cassidy.williams@stonybrook.edu      cassidy.williams@stonybrook.edu
# 10            chris.kang@stonybrook.edu            chris.kang@stonybrook.edu
# ...

# %%
df['all'] = df['L01'] + df['L02']

# %%
df['all']
# Out:
# 0     abrar.uddin@stonybrook.eduabrar.uddin@stonybro...
# 1     agam.singh@stonybrook.eduagam.singh@stonybrook...
# 2     aisha.m.ali@stonybrook.eduaisha.m.ali@stonybro...
# 3     alex.feldewerth@stonybrook.edualex.feldewerth@...
# 4     alvin.varghese@stonybrook.edualvin.varghese@st...
# 5     andrew.sahawneh@stonybrook.eduandrew.sahawneh@...
# 6     areej.niaz@stonybrook.eduareej.niaz@stonybrook...
# 7      arfan.ali@stonybrook.eduarfan.ali@stonybrook.edu
# 8     benjamin.wu.2@stonybrook.edubenjamin.wu.2@ston...
# 9     cassidy.williams@stonybrook.educassidy.william...
# 10    chris.kang@stonybrook.educhris.kang@stonybrook...
# 11    christopher.j.matteo@stonybrook.educhristopher...
# 12    elena.vecchio@stonybrook.edudhruv.thota@stonyb...
# 13    emily.clackett@stonybrook.eduelena.vecchio@sto...
# 14    evelyn.choong@stonybrook.eduemily.clackett@sto...
# 15    farhat.khan@stonybrook.eduevelyn.choong@stonyb...
# 16    grace.hessler@stonybrook.edufarhat.khan@stonyb...
# ...
